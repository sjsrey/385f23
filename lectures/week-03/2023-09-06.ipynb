# %%
import pandas as pd

# %%
data = pd.read_csv("data/shared/weather/Kumpula-June-2016-w-metadata.txt")

# %%
data.head(10)
# Out:
#       # Data file contents: Daily temperatures (mean            min  \
# 0                #                     for June 1-30           2016
# 1  # Data source: https://www.ncdc.noaa.gov/cdo-w...            NaN
# 2  # Data processing: Extracted temperatures from...   converted to
# 3          #                  comma-separated format            NaN
# 4                                                  #            NaN
# 5                         # David Whipp - 02.10.2017            NaN
# 6                                           YEARMODA           TEMP
# 7                                           20160601           65.5
# 8                                           20160602           65.8
# 9                                           20160603           68.4
#
#    max) for Kumpula  Helsinki
# 0               NaN       NaN
# 1               NaN       NaN
# 2               NaN       NaN
# 3               NaN       NaN
# 4               NaN       NaN
# 5               NaN       NaN
# 6               MAX       MIN
# 7              73.6      54.7
# 8              80.8      55.0
# 9              77.9      55.6

# %%
data.tail()
# Out:
#    # Data file contents: Daily temperatures (mean   min  max) for Kumpula  \
# 32                                       20160626  69.6              77.7
# 33                                       20160627  60.7              70.0
# 34                                       20160628  65.4              73.0
# 35                                       20160629  65.8              73.2
# 36                                       20160630  65.7              72.7
#
#     Helsinki
# 32      60.3
# 33      57.6
# 34      55.8
# 35      59.7
# 36      59.2

# %%
data = pd.read_csv("data/shared/weather/Kumpula-June-2016-w-metadata.txt", skiprows=8)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN
# 0  20160601  65.5  73.6  54.7
# 1  20160602  65.8  80.8  55.0
# 2  20160603  68.4  77.9  55.6
# 3  20160604  57.5  70.9  47.3
# 4  20160605  51.4  58.3  43.2

# %%
data.tail()
# Out:
#     YEARMODA  TEMP   MAX   MIN
# 25  20160626  69.6  77.7  60.3
# 26  20160627  60.7  70.0  57.6
# 27  20160628  65.4  73.0  55.8
# 28  20160629  65.8  73.2  59.7
# 29  20160630  65.7  72.7  59.2

# %%
temp_data = pd.read_csv(
    "data/shared/weather/Kumpula-June-2016-w-metadata.txt", 
    skiprows=8, usecols=["YEARMODA", "TEMP"]
)

temp_data.head()
# Out:
#    YEARMODA  TEMP
# 0  20160601  65.5
# 1  20160602  65.8
# 2  20160603  68.4
# 3  20160604  57.5
# 4  20160605  51.4

# %%
output_fp = "Kumpula_temps_June_2016.csv"
data.to_csv(output_fp, sep=",")

# %%
output_fp = "Kumpula_temps_June_2016.csv"
data.to_csv(output_fp, sep=",", index=False, float_format="%.0f")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
len(data)
# Out:
# 30

# %%
data.shape
# Out:
# (30, 4)

# %%
data.columns
# Out:
# Index(['YEARMODA', 'TEMP', 'MAX', 'MIN'], dtype='object')

# %%
data.columns.values
# Out:
# array(['YEARMODA', 'TEMP', 'MAX', 'MIN'], dtype=object)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
data.dtypes
# Out:
# YEARMODA      int64
# TEMP        float64
# MAX         float64
# MIN         float64
# dtype: object

# %%
selection = data[["YEARMODA", "TEMP"]]
selection.head()
# Out:
#    YEARMODA  TEMP
# 0  20160601  65.5
# 1  20160602  65.8
# 2  20160603  68.4
# 3  20160604  57.5
# 4  20160605  51.4

# %%
selection.shape
# Out:
# (30, 2)

# %%
data["TEMP"].mean()
# Out:
# 59.730000000000004

# %%
data.TEMP.mean()
# Out:
# 59.730000000000004

# %%
data.mean()
# Out:
# YEARMODA    20160615.50
# TEMP              59.73
# MAX               67.94
# MIN               51.75
# dtype: float64

# %%
data.describe()
# Out:
#            YEARMODA       TEMP        MAX        MIN
# count  3.000000e+01  30.000000  30.000000  30.000000
# mean   2.016062e+07  59.730000  67.940000  51.750000
# std    8.803408e+00   5.475472   6.651761   5.634484
# min    2.016060e+07  49.400000  54.100000  41.700000
# 25%    2.016061e+07  56.450000  63.150000  47.300000
# 50%    2.016062e+07  60.050000  69.000000  54.050000
# 75%    2.016062e+07  64.900000  72.375000  55.750000
# max    2.016063e+07  69.600000  80.800000  60.300000

# %%
data['MIN'].hasnans
# Out:
# False

# %%
data.head(30)
# Out:
#     YEARMODA  TEMP   MAX   MIN
# 0   20160601  65.5  73.6  54.7
# 1   20160602  65.8  80.8  55.0
# 2   20160603  68.4  77.9  55.6
# 3   20160604  57.5  70.9  47.3
# 4   20160605  51.4  58.3  43.2
# 5   20160606  52.2  59.7  42.8
# 6   20160607  56.9  65.1  45.9
# 7   20160608  54.2  60.4  47.5
# 8   20160609  49.4  54.1  45.7
# 9   20160610  49.5  55.9  43.0
# 10  20160611  54.0  62.1  41.7
# 11  20160612  55.4  64.2  46.0
# 12  20160613  58.3  68.2  47.3
# 13  20160614  59.7  67.8  47.8
# 14  20160615  63.4  70.3  49.3
# 15  20160616  57.8  67.5  55.6
# 16  20160617  60.4  70.7  55.9
# 17  20160618  57.3  62.8  54.0
# 18  20160619  56.3  59.2  54.1
# 19  20160620  59.3  69.1  52.2
# 20  20160621  62.6  71.4  50.4
# 21  20160622  61.7  70.2  55.4
# 22  20160623  60.9  67.1  54.9
# 23  20160624  61.1  68.9  56.7
# 24  20160625  65.7  75.4  57.9
# 25  20160626  69.6  77.7  60.3
# 26  20160627  60.7  70.0  57.6
# 27  20160628  65.4  73.0  55.8
# 28  20160629  65.8  73.2  59.7
# 29  20160630  65.7  72.7  59.2

# %% [markdown]
# ## Unique Values

# %%
data['TEMP'].unique()
# Out:
# array([65.5, 65.8, 68.4, 57.5, 51.4, 52.2, 56.9, 54.2, 49.4, 49.5, 54. ,
#        55.4, 58.3, 59.7, 63.4, 57.8, 60.4, 57.3, 56.3, 59.3, 62.6, 61.7,
#        60.9, 61.1, 65.7, 69.6, 60.7, 65.4])

# %%
print(
    "There were",
    data["TEMP"].nunique(),
    "days with unique mean temperatures in June 2016.",
)
# Out:
# There were 28 days with unique mean temperatures in June 2016.

# %%
data.TEMP.mean()
# Out:
# 59.730000000000004

# %%
data.mean()
# Out:
# YEARMODA    20160615.50
# TEMP              59.73
# MAX               67.94
# MIN               51.75
# dtype: float64

# %%
data.describe()
# Out:
#            YEARMODA       TEMP        MAX        MIN
# count  3.000000e+01  30.000000  30.000000  30.000000
# mean   2.016062e+07  59.730000  67.940000  51.750000
# std    8.803408e+00   5.475472   6.651761   5.634484
# min    2.016060e+07  49.400000  54.100000  41.700000
# 25%    2.016061e+07  56.450000  63.150000  47.300000
# 50%    2.016062e+07  60.050000  69.000000  54.050000
# 75%    2.016062e+07  64.900000  72.375000  55.750000
# max    2.016063e+07  69.600000  80.800000  60.300000

# %% [markdown]
# ## Constructing Pandas objects

# %%
number_series = pd.Series([4, 5, 6, 7.0])
print(number_series)
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3    7.0
# dtype: float64

# %%
number_series = pd.Series([4, 5, 6, 7.0], index=["a", "b", "c", "d"])
print(number_series)
# Out:
# a    4.0
# b    5.0
# c    6.0
# d    7.0
# dtype: float64

# %%
stations = ["Hanko", "Heinola", "Kaisaniemi", "Malmi"]
latitudes = [59.77, 61.2, 60.18, 60.25]
longitudes = [22.95, 26.05, 24.94, 25.05]

# %%
new_data = pd.DataFrame(data={"station": stations, "lat": latitudes, "lon": longitudes})
new_data
# Out:
#       station    lat    lon
# 0       Hanko  59.77  22.95
# 1     Heinola  61.20  26.05
# 2  Kaisaniemi  60.18  24.94
# 3       Malmi  60.25  25.05

# %%
dictionaries = [
    {"station": "Hanko", "lat": 59.77, "lon": 22.95},
    {"station": "Heinola", "lat": 61.2, "lon": 26.05},
    {"station": "Kaisaniemi", "lat": 60.18, "lon": 24.94},
    {"station": "Malmi", "lat": 60.25, "lon": 25.05},
]

# Pass the list into the DataFrame constructor
new_data_2 = pd.DataFrame(dictionaries)
new_data_2
# Out:
#       station    lat    lon
# 0       Hanko  59.77  22.95
# 1     Heinola  61.20  26.05
# 2  Kaisaniemi  60.18  24.94
# 3       Malmi  60.25  25.05

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df["lon"] = longitudes
df["lat"] = latitudes
df
# Out:
#      lon    lat
# 0  22.95  59.77
# 1  26.05  61.20
# 2  24.94  60.18
# 3  25.05  60.25

# %% [markdown]
# ## Common tabular operations

# %%
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN
# 0  20160601  65.5  73.6  54.7
# 1  20160602  65.8  80.8  55.0
# 2  20160603  68.4  77.9  55.6
# 3  20160604  57.5  70.9  47.3
# 4  20160605  51.4  58.3  43.2

# %%
data['DIFF'] = 0.0
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF
# 0  20160601  65.5  73.6  54.7   0.0
# 1  20160602  65.8  80.8  55.0   0.0
# 2  20160603  68.4  77.9  55.6   0.0
# 3  20160604  57.5  70.9  47.3   0.0
# 4  20160605  51.4  58.3  43.2   0.0

# %%
data['DIFF'].dtypes
# Out:
# dtype('float64')

# %%
data['DIFF'] = data['MAX'] - data['MIN']
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF
# 0  20160601  65.5  73.6  54.7  18.9
# 1  20160602  65.8  80.8  55.0  25.8
# 2  20160603  68.4  77.9  55.6  22.3
# 3  20160604  57.5  70.9  47.3  23.6
# 4  20160605  51.4  58.3  43.2  15.1

# %%
data["TEMP_CELSIUS"] = (data["TEMP"] - 32) / (9 / 5)
data.head()
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 0  20160601  65.5  73.6  54.7  18.9     18.611111
# 1  20160602  65.8  80.8  55.0  25.8     18.777778
# 2  20160603  68.4  77.9  55.6  22.3     20.222222
# 3  20160604  57.5  70.9  47.3  23.6     14.166667
# 4  20160605  51.4  58.3  43.2  15.1     10.777778

# %% [markdown]
# ## Selecting and updating data

# %%
selection = data[0:5]
selection
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 0  20160601  65.5  73.6  54.7  18.9     18.611111
# 1  20160602  65.8  80.8  55.0  25.8     18.777778
# 2  20160603  68.4  77.9  55.6  22.3     20.222222
# 3  20160604  57.5  70.9  47.3  23.6     14.166667
# 4  20160605  51.4  58.3  43.2  15.1     10.777778

# %%
# Select temp column values on rows 0-5
selection = data.loc[0:5, "TEMP"]
selection
# Out:
# 0    65.5
# 1    65.8
# 2    68.4
# 3    57.5
# 4    51.4
# 5    52.2
# Name: TEMP, dtype: float64

# %% [markdown]
# ### Selecting a single row

# %%
row = data.loc[4]
row
# Out:
# YEARMODA        2.016060e+07
# TEMP            5.140000e+01
# MAX             5.830000e+01
# MIN             4.320000e+01
# DIFF            1.510000e+01
# TEMP_CELSIUS    1.077778e+01
# Name: 4, dtype: float64

# %%
row["TEMP"]
# Out:
# 51.4

# %%
selection = data.loc[0:5, ["TEMP", "TEMP_CELSIUS"]]
selection
# Out:
#    TEMP  TEMP_CELSIUS
# 0  65.5     18.611111
# 1  65.8     18.777778
# 2  68.4     20.222222
# 3  57.5     14.166667
# 4  51.4     10.777778
# 5  52.2     11.222222

# %%
selection.at[0, "TEMP"]
# Out:
# 65.5

# %%
selection.loc[0, "TEMP"]
# Out:
# 65.5

# %% [markdown]
# ### Selection by position

# %%
# Check the first rows
print(data.head())
print()
print("Value at position (0,0) is", data.iloc[0, 0])
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 0  20160601  65.5  73.6  54.7  18.9     18.611111
# 1  20160602  65.8  80.8  55.0  25.8     18.777778
# 2  20160603  68.4  77.9  55.6  22.3     20.222222
# 3  20160604  57.5  70.9  47.3  23.6     14.166667
# 4  20160605  51.4  58.3  43.2  15.1     10.777778
#
# Value at position (0,0) is 20160601

# %%
data.iloc[-1, -1]
# Out:
# 18.722222222222225

# %%
data.tail()
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 25  20160626  69.6  77.7  60.3  17.4     20.888889
# 26  20160627  60.7  70.0  57.6  12.4     15.944444
# 27  20160628  65.4  73.0  55.8  17.2     18.555556
# 28  20160629  65.8  73.2  59.7  13.5     18.777778
# 29  20160630  65.7  72.7  59.2  13.5     18.722222

# %%
data.iloc[-1, -2]
# Out:
# 13.5

# %% [markdown]
# ## Selections using listed criteria

# %%
# List of values that will be used as basis for selecting the rows
selection_criteria = [20160601, 20160608, 20160609]

# Do the selection based on criteria applied to YEARMODA column
data.loc[data["YEARMODA"].isin(selection_criteria)]
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 0  20160601  65.5  73.6  54.7  18.9     18.611111
# 7  20160608  54.2  60.4  47.5  12.9     12.333333
# 8  20160609  49.4  54.1  45.7   8.4      9.666667

# %% [markdown]
# ## Conditional selection

# %%
data.TEMP_CELSIUS > 15
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# Name: TEMP_CELSIUS, dtype: bool

# %%
warm_temps = data[data.TEMP_CELSIUS > 15]
warm_temps
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 0   20160601  65.5  73.6  54.7  18.9     18.611111
# 1   20160602  65.8  80.8  55.0  25.8     18.777778
# 2   20160603  68.4  77.9  55.6  22.3     20.222222
# 13  20160614  59.7  67.8  47.8  20.0     15.388889
# 14  20160615  63.4  70.3  49.3  21.0     17.444444
# 16  20160617  60.4  70.7  55.9  14.8     15.777778
# 19  20160620  59.3  69.1  52.2  16.9     15.166667
# 20  20160621  62.6  71.4  50.4  21.0     17.000000
# 21  20160622  61.7  70.2  55.4  14.8     16.500000
# 22  20160623  60.9  67.1  54.9  12.2     16.055556
# 23  20160624  61.1  68.9  56.7  12.2     16.166667
# 24  20160625  65.7  75.4  57.9  17.5     18.722222
# 25  20160626  69.6  77.7  60.3  17.4     20.888889
# 26  20160627  60.7  70.0  57.6  12.4     15.944444
# 27  20160628  65.4  73.0  55.8  17.2     18.555556
# 28  20160629  65.8  73.2  59.7  13.5     18.777778
# 29  20160630  65.7  72.7  59.2  13.5     18.722222

# %%
warm_temps = data[(data["TEMP_CELSIUS"] > 15) & (data["YEARMODA"] >= 20160615)]
warm_temps
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 14  20160615  63.4  70.3  49.3  21.0     17.444444
# 16  20160617  60.4  70.7  55.9  14.8     15.777778
# 19  20160620  59.3  69.1  52.2  16.9     15.166667
# 20  20160621  62.6  71.4  50.4  21.0     17.000000
# 21  20160622  61.7  70.2  55.4  14.8     16.500000
# 22  20160623  60.9  67.1  54.9  12.2     16.055556
# 23  20160624  61.1  68.9  56.7  12.2     16.166667
# 24  20160625  65.7  75.4  57.9  17.5     18.722222
# 25  20160626  69.6  77.7  60.3  17.4     20.888889
# 26  20160627  60.7  70.0  57.6  12.4     15.944444
# 27  20160628  65.4  73.0  55.8  17.2     18.555556
# 28  20160629  65.8  73.2  59.7  13.5     18.777778
# 29  20160630  65.7  72.7  59.2  13.5     18.722222

# %% [markdown]
# Selectoins### Reset index

# %%
warm_temps = warm_temps.reset_index(drop=True)
warm_temps
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 0   20160615  63.4  70.3  49.3  21.0     17.444444
# 1   20160617  60.4  70.7  55.9  14.8     15.777778
# 2   20160620  59.3  69.1  52.2  16.9     15.166667
# 3   20160621  62.6  71.4  50.4  21.0     17.000000
# 4   20160622  61.7  70.2  55.4  14.8     16.500000
# 5   20160623  60.9  67.1  54.9  12.2     16.055556
# 6   20160624  61.1  68.9  56.7  12.2     16.166667
# 7   20160625  65.7  75.4  57.9  17.5     18.722222
# 8   20160626  69.6  77.7  60.3  17.4     20.888889
# 9   20160627  60.7  70.0  57.6  12.4     15.944444
# 10  20160628  65.4  73.0  55.8  17.2     18.555556
# 11  20160629  65.8  73.2  59.7  13.5     18.777778
# 12  20160630  65.7  72.7  59.2  13.5     18.722222

# %%
warm_temps["MIN"].hasnans
# Out:
# False

# %% [markdown]
# ## Sorting Data

# %%
data.sort_values(by="TEMP").head()
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 8   20160609  49.4  54.1  45.7   8.4      9.666667
# 9   20160610  49.5  55.9  43.0  12.9      9.722222
# 4   20160605  51.4  58.3  43.2  15.1     10.777778
# 5   20160606  52.2  59.7  42.8  16.9     11.222222
# 10  20160611  54.0  62.1  41.7  20.4     12.222222

# %%
data.sort_values(by="TEMP", ascending=False).head()
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS
# 25  20160626  69.6  77.7  60.3  17.4     20.888889
# 2   20160603  68.4  77.9  55.6  22.3     20.222222
# 1   20160602  65.8  80.8  55.0  25.8     18.777778
# 28  20160629  65.8  73.2  59.7  13.5     18.777778
# 29  20160630  65.7  72.7  59.2  13.5     18.722222

# %%
# Create a list of weekdays that matches with our data
# The data covers 4 weeks + 2 days (i.e. altogether 30 days)
week_days = ["Wed", "Thu", "Fri", "Sat", "Sun", "Mon", "Tue"]
day_list = week_days * 4 + week_days[:2]

# Add the weekdays to our DataFrame
data["WEEKDAY"] = day_list
data.head(10)
# Out:
#    YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS WEEKDAY
# 0  20160601  65.5  73.6  54.7  18.9     18.611111     Wed
# 1  20160602  65.8  80.8  55.0  25.8     18.777778     Thu
# 2  20160603  68.4  77.9  55.6  22.3     20.222222     Fri
# 3  20160604  57.5  70.9  47.3  23.6     14.166667     Sat
# 4  20160605  51.4  58.3  43.2  15.1     10.777778     Sun
# 5  20160606  52.2  59.7  42.8  16.9     11.222222     Mon
# 6  20160607  56.9  65.1  45.9  19.2     13.833333     Tue
# 7  20160608  54.2  60.4  47.5  12.9     12.333333     Wed
# 8  20160609  49.4  54.1  45.7   8.4      9.666667     Thu
# 9  20160610  49.5  55.9  43.0  12.9      9.722222     Fri

# %%
data.sort_values(by=["WEEKDAY", "TEMP_CELSIUS"], ascending=[True, False]).head(10)
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS WEEKDAY
# 2   20160603  68.4  77.9  55.6  22.3     20.222222     Fri
# 23  20160624  61.1  68.9  56.7  12.2     16.166667     Fri
# 16  20160617  60.4  70.7  55.9  14.8     15.777778     Fri
# 9   20160610  49.5  55.9  43.0  12.9      9.722222     Fri
# 26  20160627  60.7  70.0  57.6  12.4     15.944444     Mon
# 19  20160620  59.3  69.1  52.2  16.9     15.166667     Mon
# 12  20160613  58.3  68.2  47.3  20.9     14.611111     Mon
# 5   20160606  52.2  59.7  42.8  16.9     11.222222     Mon
# 24  20160625  65.7  75.4  57.9  17.5     18.722222     Sat
# 3   20160604  57.5  70.9  47.3  23.6     14.166667     Sat

# %%
data.sort_values(by=["WEEKDAY"], ascending=[True]).head(10)
# Out:
#     YEARMODA  TEMP   MAX   MIN  DIFF  TEMP_CELSIUS WEEKDAY
# 2   20160603  68.4  77.9  55.6  22.3     20.222222     Fri
# 16  20160617  60.4  70.7  55.9  14.8     15.777778     Fri
# 23  20160624  61.1  68.9  56.7  12.2     16.166667     Fri
# 9   20160610  49.5  55.9  43.0  12.9      9.722222     Fri
# 12  20160613  58.3  68.2  47.3  20.9     14.611111     Mon
# 19  20160620  59.3  69.1  52.2  16.9     15.166667     Mon
# 5   20160606  52.2  59.7  42.8  16.9     11.222222     Mon
# 26  20160627  60.7  70.0  57.6  12.4     15.944444     Mon
# 17  20160618  57.3  62.8  54.0   8.8     14.055556     Sat
# 10  20160611  54.0  62.1  41.7  20.4     12.222222     Sat

# %% [markdown]
# ## Visualization

# %%
import seaborn as sns
sns.set()

# %%
import pandas

# %%
df = pandas.read_csv("data/shared/covid/covid_combined.csv",
                     index_col='date', parse_dates=True)

# %%
df.head()
# Out:
#                  state  fips  cases  deaths  dtc100  population  deaths100k
# date
# 2020-01-21  Washington    53      1       0     0.0     7614893         0.0
# 2020-01-22  Washington    53      1       0     0.0     7614893         0.0
# 2020-01-23  Washington    53      1       0     0.0     7614893         0.0
# 2020-01-24  Washington    53      1       0     0.0     7614893         0.0
# 2020-01-25  Washington    53      1       0     0.0     7614893         0.0

# %%
df.tail()
# Out:
#                                state  fips  cases  deaths    dtc100  \
# date
# 2020-07-29  Northern Mariana Islands    69     40       2  5.000000
# 2020-07-30  Northern Mariana Islands    69     42       2  4.761905
# 2020-07-31  Northern Mariana Islands    69     42       2  4.761905
# 2020-08-01  Northern Mariana Islands    69     44       2  4.545455
# 2020-08-02  Northern Mariana Islands    69     45       2  4.444444
#
#             population  deaths100k
# date
# 2020-07-29       55194    3.623582
# 2020-07-30       55194    3.623582
# 2020-07-31       55194    3.623582
# 2020-08-01       55194    3.623582
# 2020-08-02       55194    3.623582

# %%
df.shape
# Out:
# (8287, 7)

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30',
#                ...
#                '2020-07-24', '2020-07-25', '2020-07-26', '2020-07-27',
#                '2020-07-28', '2020-07-29', '2020-07-30', '2020-07-31',
#                '2020-08-01', '2020-08-02'],
#               dtype='datetime64[ns]', name='date', length=8287, freq=None)

# %%
last_df = df.loc['2020-08-02']

# %%
last_df.shape
# Out:
# (54, 7)

# %%
last_df.reset_index(inplace=True)
last_df
# Out:
#          date                     state  fips   cases  deaths    dtc100  \
# 0  2020-08-02                Washington    53   60161    1680  2.792507
# 1  2020-08-02                  Illinois    17  183662    7718  4.202285
# 2  2020-08-02                California     6  515937    9399  1.821734
# 3  2020-08-02                   Arizona     4  178473    3769  2.111804
# 4  2020-08-02             Massachusetts    25  118458    8638  7.292036
# 5  2020-08-02                 Wisconsin    55   58990     956  1.620614
# 6  2020-08-02                     Texas    48  452826    7515  1.659578
# 7  2020-08-02                  Nebraska    31   26702     338  1.265823
# 8  2020-08-02                      Utah    49   41175     313  0.760170
# 9  2020-08-02                    Oregon    41   19097     331  1.733257
# 10 2020-08-02                   Florida    12  487124    7083  1.454045
# 11 2020-08-02                  New York    36  421008   32401  7.696053
# 12 2020-08-02              Rhode Island    44   19022    1007  5.293870
# 13 2020-08-02                   Georgia    13  177556    3758  2.116515
# 14 2020-08-02             New Hampshire    33    6634     417  6.285800
# 15 2020-08-02            North Carolina    37  125339    1996  1.592481
# 16 2020-08-02                New Jersey    34  184225   15836  8.596010
# 17 2020-08-02                  Colorado     8   47799    1846  3.862005
# 18 2020-08-02                  Maryland    24   90835    3515  3.869654
# 19 2020-08-02                    Nevada    32   50270     833  1.657052
# 20 2020-08-02                 Tennessee    47  106804    1062  0.994345
# 21 2020-08-02                    Hawaii    15    2219      25  1.126634
# 22 2020-08-02                   Indiana    18   69531    2975  4.278667
# 23 2020-08-02                  Kentucky    21   31966     759  2.374398
# 24 2020-08-02                 Minnesota    27   55987    1654  2.954257
# 25 2020-08-02                  Oklahoma    40   38201     550  1.439753
# 26 2020-08-02              Pennsylvania    42  118038    7274  6.162422
# 27 2020-08-02            South Carolina    45   91788    1777  1.935983
# 28 2020-08-02      District of Columbia    11   12274     586  4.774320
# 29 2020-08-02                    Kansas    20   28341     361  1.273773
# 30 2020-08-02                  Missouri    29   52550    1311  2.494767
# 31 2020-08-02                   Vermont    50    1426      57  3.997195
# 32 2020-08-02                  Virginia    51   91782    2218  2.416596
# 33 2020-08-02               Connecticut     9   49810    4432  8.897812
# 34 2020-08-02                      Iowa    19   45723     878  1.920259
# 35 2020-08-02                 Louisiana    22  119861    4007  3.343039
# 36 2020-08-02                      Ohio    39   93031    3529  3.793359
# 37 2020-08-02                  Michigan    26   91857    6460  7.032670
# 38 2020-08-02              South Dakota    46    8955     135  1.507538
# 39 2020-08-02                  Arkansas     5   43810     464  1.059119
# 40 2020-08-02                  Delaware    10   14949     585  3.913305
# 41 2020-08-02               Mississippi    28   60553    1703  2.812412
# 42 2020-08-02                New Mexico    35   21016     654  3.111915
# 43 2020-08-02              North Dakota    38    6664     109  1.635654
# 44 2020-08-02                   Wyoming    56    2808      26  0.925926
# 45 2020-08-02                    Alaska     2    3982      22  0.552486
# 46 2020-08-02                     Maine    23    3958     123  3.107630
# 47 2020-08-02                   Alabama     1   91444    1627  1.779231
# 48 2020-08-02                     Idaho    16   21465     197  0.917773
# 49 2020-08-02                   Montana    30    4193      61  1.454806
# 50 2020-08-02               Puerto Rico    72   18411     230  1.249253
# 51 2020-08-02                      Guam    66    1328       6  0.451807
# 52 2020-08-02             West Virginia    54    6854     117  1.707032
# 53 2020-08-02  Northern Mariana Islands    69      45       2  4.444444
#
#     population  deaths100k
# 0      7614893   22.062030
# 1     12671821   60.906795
# 2     39512223   23.787576
# 3      7278717   51.781104
# 4      6949503  124.296658
# 5      5822434   16.419250
# 6     28995881   25.917474
# 7      1934408   17.473046
# 8      3205958    9.763072
# 9      4217737    7.847810
# 10    21477737   32.978335
# 11    19453561  166.555624
# 12     1059361   95.057303
# 13    10617423   35.394653
# 14     1359711   30.668282
# 15    10488084   19.031121
# 16     8882190  178.289363
# 17     5758736   32.055646
# 18     6045680   58.140689
# 19     3080156   27.044085
# 20     6833174   15.541826
# 21     1415872    1.765696
# 22     6732219   44.190482
# 23     4467673   16.988710
# 24     5639632   29.328155
# 25     3956971   13.899521
# 26    12801989   56.819296
# 27     5148714   34.513473
# 28      705749   83.032353
# 29     2913314   12.391387
# 30     6137428   21.360739
# 31      623989    9.134776
# 32     8535519   25.985532
# 33     3565287  124.309768
# 34     3155070   27.828226
# 35     4648794   86.194398
# 36    11689100   30.190519
# 37     9986857   64.685016
# 38      884659   15.260117
# 39     3017825   15.375312
# 40      973764   60.076158
# 41     2976149   57.221597
# 42     2096829   31.189954
# 43      762062   14.303298
# 44      578759    4.492371
# 45      731545    3.007334
# 46     1344212    9.150342
# 47     4903185   33.182513
# 48     1787065   11.023662
# 49     1068778    5.707453
# 50     3193694    7.201692
# 51      165718    3.620609
# 52     1792147    6.528482
# 53       55194    3.623582

# %%
_ = sns.displot(last_df.deaths100k)

# %%
_ = sns.displot(last_df.deaths100k, rug=True)
