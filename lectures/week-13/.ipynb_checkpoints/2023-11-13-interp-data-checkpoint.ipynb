# %%
import rasterio

# %%
from rasterio.mask import mask
import geopandas as gpd
import fiona
import pandas as pd

# %% [markdown]
# ## Raster Data on California Precipitation
#
# - 800m cell resolution
# - annual precipitation in inches

# %%
ras = 'data/stanford-td754wr4701-geotiff.tiff' # already interpolated but we will treat it as "data"

# source: https://earthworks.stanford.edu/catalog/stanford-td754wr4701

# %%
rast = rasterio.open(ras)

# %%
from rasterio.plot import show

# %%
show(rast)
# Out:
# <Axes: >

# %%
from rasterio.plot import show_hist

show_hist(rast, lw=0.0, stacked=False, alpha=0.3, 
          histtype='stepfilled', title="Histogram");

# %% [markdown]
# ## Clip to San Diego County

# %%
gdf = gpd.read_file('sdcounty.geojson')

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
county = gdf.to_crs(rast.crs)

# %%
county.plot()
# Out:
# <Axes: >

# %%
rast.crs
# Out:
# CRS.from_epsg(4326)

# %%
coords = gdf.geometry
src = rast
df = county
import matplotlib.pyplot as plt
from rasterio.plot import show

# %%
clipped_array, clipped_transform = mask(dataset=src, shapes=coords, crop=True)

df = df.to_crs(src.crs)
out_meta = src.meta.copy()
out_meta.update({"driver": "GTiff",
                 "height": clipped_array.shape[1],## 
                 "width": clipped_array.shape[2],
                 "transform": clipped_transform})
out_tif= "clipped_example.tif"
with rasterio.open(out_tif, "w", **out_meta) as dest:
    dest.write(clipped_array)
    
clipped = rasterio.open(out_tif)
fig, ax = plt.subplots(figsize=(8, 6))
p1 = df.plot(color=None,facecolor='none',edgecolor='red',linewidth = 2,ax=ax)
show(clipped, ax=ax)
ax.axis('off');

# %%
clipped
# Out:
# <open DatasetReader name='clipped_example.tif' mode='r'>

# %%
import rioxarray

# %%
d = rioxarray.open_rasterio("clipped_example.tif")

# %%
d
# Out:
# <xarray.DataArray (band: 1, y: 336, x: 527)>
# [177072 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -117.6 -117.6 -117.6 ... -116.1 -116.1 -116.1
#   * y            (y) float64 33.5 33.5 33.5 33.5 ... 32.54 32.53 32.53 32.53
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
d.plot()

# %%
d.values.max()
# Out:
# 49

# %%
d.plot()

# %%
type(d)
# Out:
# xarray.core.dataarray.DataArray

# %%
d.dims
# Out:
# ('band', 'y', 'x')

# %%
d.values.mean()
# Out:
# 15.630963675792898

# %%
import numpy

# %%
numpy.median(d.values)
# Out:
# 17.0

# %%
d.values.shape
# Out:
# (1, 336, 527)

# %%
d.plot()

# %%
d.plot.hist()
# Out:
# (array([44849., 17108., 10090., 29702., 31657., 23051., 11786.,  6411.,
#          2011.,   407.]),
#  array([ 0. ,  4.9,  9.8, 14.7, 19.6, 24.5, 29.4, 34.3, 39.2, 44.1, 49. ]),
#  <BarContainer object of 10 artists>)

# %%
type(d)
# Out:
# xarray.core.dataarray.DataArray

# %% [markdown]
# ### Sampling the raster for "observations"

# %%
import numpy
numpy.random.seed(12345)
sample_points = county.sample_points(50)

# %%
m = county.explore()
sample_points.explore(m=m, color='red')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_123e38684b468b2eb2bdb9f29e9a87da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_123e38684b468b2eb2bdb9f29e9a87da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_123e38684b468b2eb2bdb9f29e9a87da = L.map(
#                 &quot;map_123e38684b468b2eb2bdb9f29e9a87da&quot;,
#                 {
#                     center: [33.01692888387243, -116.84601082562747],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_123e38684b468b2eb2bdb9f29e9a87da);
#
#
#
#
#
#             var tile_layer_134d9a96e61d5816d3809055708c1587 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_123e38684b468b2eb2bdb9f29e9a87da);
#
#
#             map_123e38684b468b2eb2bdb9f29e9a87da.fitBounds(
#                 [[32.528832, -117.61108067385622], [33.50502576774486, -116.08094097739871]],
#                 {}
#             );
#
#
#         function geo_json_0af9ac9839700a32cf0d58b3b398d0e0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0af9ac9839700a32cf0d58b3b398d0e0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0af9ac9839700a32cf0d58b3b398d0e0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0af9ac9839700a32cf0d58b3b398d0e0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0af9ac9839700a32cf0d58b3b398d0e0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0af9ac9839700a32cf0d58b3b398d0e0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0af9ac9839700a32cf0d58b3b398d0e0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0af9ac9839700a32cf0d58b3b398d0e0 = L.geoJson(null, {
#                 onEachFeature: geo_json_0af9ac9839700a32cf0d58b3b398d0e0_onEachFeature,
#
#                 style: geo_json_0af9ac9839700a32cf0d58b3b398d0e0_styler,
#                 pointToLayer: geo_json_0af9ac9839700a32cf0d58b3b398d0e0_pointToLayer
#         });
#
#         function geo_json_0af9ac9839700a32cf0d58b3b398d0e0_add (data) {
#             geo_json_0af9ac9839700a32cf0d58b3b398d0e0
#                 .addData(data)
#                 .addTo(map_123e38684b468b2eb2bdb9f29e9a87da);
#         }
#             geo_json_0af9ac9839700a32cf0d58b3b398d0e0_add({&quot;bbox&quot;: [-117.61108067385622, 32.528832, -116.08094097739871, 33.50502576774486], &quot;feat

# %% [markdown]
# ### Ensure sample points are separated by some threshold

# %%
county.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
orig_crs = county.crs

# %%
county_utm = county.to_crs(county.estimate_utm_crs())

# %%
county_utm.plot()
# Out:
# <Axes: >

# %%
threshold = 10000 # no pair of stations within 10000 meters of each other

# %%
n_points = 25 # number of stations desired

# %%
numpy.random.seed(12345)
thinning = True
sample_points = county_utm.sample_points(n_points * 4).explode(index_parts=True)
candidates = []
t2 = threshold**2
iter = 0
while thinning:
    p0 = numpy.random.choice(sample_points,1)[0]
    #p0 = sample_points[0]
    d0 = (sample_points.x - p0.x)**2 + (sample_points.y - p0.y)**2
    candidates.append(p0)
    if len(candidates) == n_points:
        thinning=False
    else:
        sample_points = sample_points[d0>t2]
    #print('iter: ', iter, 'shape sp: ', sampled_points.shape)
    iter += 1

# %%
cp = gpd.GeoSeries(candidates)

# %%
cp.plot()
# Out:
# <Axes: >

# %%
m = county_utm.plot()
cp.plot(ax=m, color='r');

# %%
cp.crs = county_utm.crs
cp = cp.to_crs(county.crs)

# %%
m = county.explore()
cp.explore(m=m, color='r')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21a699146680579d40309c53bcd7b374 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21a699146680579d40309c53bcd7b374&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21a699146680579d40309c53bcd7b374 = L.map(
#                 &quot;map_21a699146680579d40309c53bcd7b374&quot;,
#                 {
#                     center: [33.01692888387243, -116.84601082562747],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_21a699146680579d40309c53bcd7b374);
#
#
#
#
#
#             var tile_layer_59437ae5815c0a9945d50126d2a4bb53 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21a699146680579d40309c53bcd7b374);
#
#
#             map_21a699146680579d40309c53bcd7b374.fitBounds(
#                 [[32.528832, -117.61108067385622], [33.50502576774486, -116.08094097739871]],
#                 {}
#             );
#
#
#         function geo_json_8857d244c3e4453ed484d7eb6ff57b1b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8857d244c3e4453ed484d7eb6ff57b1b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8857d244c3e4453ed484d7eb6ff57b1b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8857d244c3e4453ed484d7eb6ff57b1b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8857d244c3e4453ed484d7eb6ff57b1b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8857d244c3e4453ed484d7eb6ff57b1b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8857d244c3e4453ed484d7eb6ff57b1b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8857d244c3e4453ed484d7eb6ff57b1b = L.geoJson(null, {
#                 onEachFeature: geo_json_8857d244c3e4453ed484d7eb6ff57b1b_onEachFeature,
#
#                 style: geo_json_8857d244c3e4453ed484d7eb6ff57b1b_styler,
#                 pointToLayer: geo_json_8857d244c3e4453ed484d7eb6ff57b1b_pointToLayer
#         });
#
#         function geo_json_8857d244c3e4453ed484d7eb6ff57b1b_add (data) {
#             geo_json_8857d244c3e4453ed484d7eb6ff57b1b
#                 .addData(data)
#                 .addTo(map_21a699146680579d40309c53bcd7b374);
#         }
#             geo_json_8857d244c3e4453ed484d7eb6ff57b1b_add({&quot;bbox&quot;: [-117.61108067385622, 32.528832, -116.08094097739871, 33.50502576774486], &quot;feat

# %%
coord_list = [(x, y) for x, y in zip(cp.x, cp.y)]

observations = [x[0] for x in clipped.sample(coord_list)]
precip_gdf = gpd.GeoDataFrame(data=observations, columns=['inches'], geometry=cp)

# %%
precip_gdf.plot(column='inches', legend=True);

# %%
m = county.explore()
precip_gdf.explore(column='inches', m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91a86576c3fd929d16caa042414ba864 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91a86576c3fd929d16caa042414ba864&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91a86576c3fd929d16caa042414ba864 = L.map(
#                 &quot;map_91a86576c3fd929d16caa042414ba864&quot;,
#                 {
#                     center: [33.01692888387243, -116.84601082562747],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_91a86576c3fd929d16caa042414ba864);
#
#
#
#
#
#             var tile_layer_ce8c4f4f3753aa841002f0f97b1300eb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_91a86576c3fd929d16caa042414ba864);
#
#
#             map_91a86576c3fd929d16caa042414ba864.fitBounds(
#                 [[32.528832, -117.61108067385622], [33.50502576774486, -116.08094097739871]],
#                 {}
#             );
#
#
#         function geo_json_3f8b8b2b37fbbb611119cf41e94ac587_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3f8b8b2b37fbbb611119cf41e94ac587_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3f8b8b2b37fbbb611119cf41e94ac587_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3f8b8b2b37fbbb611119cf41e94ac587_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3f8b8b2b37fbbb611119cf41e94ac587_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_3f8b8b2b37fbbb611119cf41e94ac587.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3f8b8b2b37fbbb611119cf41e94ac587_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3f8b8b2b37fbbb611119cf41e94ac587 = L.geoJson(null, {
#                 onEachFeature: geo_json_3f8b8b2b37fbbb611119cf41e94ac587_onEachFeature,
#
#                 style: geo_json_3f8b8b2b37fbbb611119cf41e94ac587_styler,
#                 pointToLayer: geo_json_3f8b8b2b37fbbb611119cf41e94ac587_pointToLayer
#         });
#
#         function geo_json_3f8b8b2b37fbbb611119cf41e94ac587_add (data) {
#             geo_json_3f8b8b2b37fbbb611119cf41e94ac587
#                 .addData(data)
#                 .addTo(map_91a86576c3fd929d16caa042414ba864);
#         }
#             geo_json_3f8b8b2b37fbbb611119cf41e94ac587

# %%
precip_gdf.to_file("precip_sd.geojson", driver='GeoJSON')
county.to_file("sdcounty.geojson", driver='GeoJSON')
