# %% [markdown]
# # Spatial Interpolation

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 9)

# %%
import rasterio

# %%
from rasterio.mask import mask
import geopandas as gpd
import fiona
import pandas as pd

# %%
precip = gpd.read_file("precip_sd.geojson")

# %%
precip.plot(column='inches', legend=True);

# %%
county = gpd.read_file("sdcounty.geojson")

# %%
m = county.explore()
precip.explore(column='inches', m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_016300f3f755d362df819528e274f6bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_016300f3f755d362df819528e274f6bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_016300f3f755d362df819528e274f6bc = L.map(
#                 &quot;map_016300f3f755d362df819528e274f6bc&quot;,
#                 {
#                     center: [33.01692888387243, -116.84601082562747],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_016300f3f755d362df819528e274f6bc);
#
#
#
#
#
#             var tile_layer_470a0f00cc802208d9241d21ea168690 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_016300f3f755d362df819528e274f6bc);
#
#
#             map_016300f3f755d362df819528e274f6bc.fitBounds(
#                 [[32.528832, -117.61108067385622], [33.50502576774486, -116.08094097739871]],
#                 {}
#             );
#
#
#         function geo_json_d92f731462e927503a0f9142cefa5592_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d92f731462e927503a0f9142cefa5592_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d92f731462e927503a0f9142cefa5592_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d92f731462e927503a0f9142cefa5592_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d92f731462e927503a0f9142cefa5592_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d92f731462e927503a0f9142cefa5592.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d92f731462e927503a0f9142cefa5592_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d92f731462e927503a0f9142cefa5592 = L.geoJson(null, {
#                 onEachFeature: geo_json_d92f731462e927503a0f9142cefa5592_onEachFeature,
#
#                 style: geo_json_d92f731462e927503a0f9142cefa5592_styler,
#                 pointToLayer: geo_json_d92f731462e927503a0f9142cefa5592_pointToLayer
#         });
#
#         function geo_json_d92f731462e927503a0f9142cefa5592_add (data) {
#             geo_json_d92f731462e927503a0f9142cefa5592
#                 .addData(data)
#                 .addTo(map_016300f3f755d362df819528e274f6bc);
#         }
#             geo_json_d92f731462e927503a0f9142cefa5592

# %% [markdown]
# ## Interpolation Methods

# %% [markdown]
# ### Voronoi Partition Interpolation

# %%
from libpysal.cg import voronoi_frames
points = [(10.2, 5.1), (4.7, 2.2), (5.3, 5.7), (2.7, 5.3)]
regions_df, points_df = voronoi_frames(points)
regions_df.shape
(4, 1)
# Out:
# (4, 1)

# %%
regions_df.plot()
# Out:
# <Axes: >

# %%
#libpysal.cg.voronoi_frames(points, radius=None, clip='extent')
points = precip.get_coordinates().values

# %%
points
# Out:
# array([[-116.1109184 ,   32.76324713],
#        [-117.06489923,   32.9450013 ],
#        [-117.47040687,   33.33271356],
#        [-116.89570655,   33.18820403],
#        [-116.78158302,   32.60515765],
#        [-116.90200424,   32.57955754],
#        [-116.96432212,   32.66470908],
#        [-117.39576004,   33.11915699],
#        [-116.35690155,   32.97594533],
#        [-117.19710121,   32.67468685],
#        [-117.16209441,   32.76401542],
#        [-117.13675066,   32.59013732],
#        [-117.16915537,   33.32893615],
#        [-116.79142906,   32.90300922],
#        [-116.75035578,   33.3714751 ],
#        [-116.41592121,   33.33728691],
#        [-117.26238097,   33.0812988 ],
#        [-116.19999127,   32.91698325],
#        [-116.27826361,   33.07063673],
#        [-116.56366288,   33.00616311],
#        [-116.46530036,   32.73445089],
#        [-116.25689724,   32.6285559 ],
#        [-116.10421319,   33.08427021],
#        [-116.4320357 ,   32.85741299],
#        [-116.55208202,   33.34419029]])

# %%
v_gdf, v_p = voronoi_frames(points)

v_gdf.plot()
# Out:
# <Axes: >

# %%
v_gdf, v_p = voronoi_frames(points, clip=county.geometry[0])

v_gdf.plot()
# Out:
# <Axes: >

# %%
v_gdf['inches'] = precip.inches

# %%
v_gdf.plot(column='inches', legend=True)
# Out:
# <Axes: >

# %%
base = v_gdf.plot(column='inches', legend=True,
                 edgecolor='gray')
precip.plot(ax=base, color='w');

# %% [markdown]
# ### Interpolate to Grids
#
# - hex3 the county
# - nearest neighbor interpolators
# -

# %%
import tobler

# %%
county_utm = county.to_crs(county.estimate_utm_crs())
precip_utm = precip.to_crs(precip.estimate_utm_crs())

# %%
from tobler.util import h3fy

# %%
county_h3 = h3fy(county_utm)
# Out:
# /home/serge/miniforge3/envs/385f23/lib/python3.11/site-packages/pyproj/crs/crs.py:1293: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/385f23/lib/python3.11/site-packages/tobler/util/util.py:184, in _to_hex(source, resolution, return_geoms, buffer)
#     183 try:
# --> 184     import h3
#     185 except ImportError:
#
# ModuleNotFoundError: No module named 'h3'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 county_h3 = h3fy(county_utm)
#
# File ~/miniforge3/envs/385f23/lib/python3.11/site-packages/tobler/util/util.py:144, in h3fy(source, resolution, clip, buffer, return_geoms)
#     141 source_unary = source.unary_union
#     143 if type(source_unary) == Polygon:
# --> 144     hexagons = _to_hex(
#     145         source_unary, resolution=resolution, return_geoms=return_geoms
#     146     )
#     147 else:
#     148     output = []
#
# File ~/miniforge3/envs/385f23/lib/python3.11/site-packages/tobler/util/util.py:186, in _to_hex(source, resolution, return_geoms, buffer)
#     184     import h3
#     185 except ImportError:
# --> 186     raise ImportError(
#     187         "This function requires the `h3` library. "
#     188         "You can install it with `conda install h3-py` or "
#     189         "`pip install h3`"
#     190     )
#     192 hexids = pandas.Series(
#     193     list(
#     194         h3.polyfill(
#    (...)
#     200     name="hex_id",
#     201 )
#     203 if not return_geoms:
#
# ImportError: This function requires the `h3` library. You can install it with `conda install h3-py` or `pip install h3`

# %%
county_h3.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 county_h3.plot()
#
# NameError: name 'county_h3' is not defined

# %%
m = county_h3.plot(color='grey')
precip_utm.plot(column='inches', ax=m, legend=True);

# %% [markdown]
# ### Nearest neighbor

# %%
hcents = county_h3.centroid

# %%
m = hcents.plot(color='r')
precip_utm.plot(column='inches', ax=m, legend=True);

# %%
gpd.sjoin_nearest(county_h3, precip_utm, distance_col="distances",
    lsuffix="left", rsuffix="right", exclusive=True)

# %%
county_h3.shape

# %%
county_h3['nn1_est'] = gpd.sjoin_nearest(county_h3, precip_utm, distance_col="distances",
    lsuffix="left", rsuffix="right", exclusive=True).inches

# %%
county_h3.plot(column='nn1_est', legend=True);

# %% [markdown]
# ### Knn5

# %%
X = [[0], [1], [2], [3]]
y = [0, 0, 1, 1]
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X, y)
print(neigh.predict([[1.5]]))

# %%
# Set number of neighbors to use
neighbors = 5

# Initialize KNN regressor
knn_regressor = KNeighborsRegressor(n_neighbors = neighbors, weights = "uniform") # no distance decay distance

# Fit to observed locations
knn_regressor.fit(precip_utm.get_coordinates(), precip_utm.inches)

# %%
knn_regressor.predict(hcents.get_coordinates())

# %%
county_h3['nn5_est'] = knn_regressor.predict(hcents.get_coordinates())

# %%
county_h3.plot(column='nn5_est', legend=True);

# %%
import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
county_h3.plot(column='nn1_est',ax=ax1)
county_h3.plot(column='nn5_est',ax=ax2)
ax1.set_title("knn=1")
ax2.set_title("knn=5");

# %%
# Set number of neighbors to use
neighbors = 5

# Initialize KNN regressor
knn_regressor = KNeighborsRegressor(n_neighbors = neighbors, weights = "distance") # inverse distance weighting
# Fit to observed locations
knn_regressor.fit(precip_utm.get_coordinates(), precip_utm.inches)

# %%
county_h3['nn5id_est'] = knn_regressor.predict(hcents.get_coordinates())

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
county_h3.plot(column='nn5_est',ax=ax1)
county_h3.plot(column='nn5id_est',ax=ax2)
ax1.set_title("knn=5 (Unweighted)")
ax2.set_title("knn=5 (Inverse Distance Weights)");

# %% [markdown]
# ## Next

# %%
tracts = gdf.dissolve(by='TRACTCE20')

tracts.shape

# %% [markdown]
# ### Surface to Area Interpolation

# %% [markdown]
# #### Spatial Join on Centroid

# %%
cents = tracts.centroid

# %%
cents.plot()

# %%
type(cents)

# %%
coord_list = [(x, y) for x, y in zip(cents.x, cents.y)]
tracts['centest'] = [x[0] for x in clipped.sample(coord_list)]
tracts.head()

# %%
tracts['centroid'] = tracts.centroid
tracts.set_geometry('centroid', inplace=True)

# %%
tracts.plot(column='centest', legend=True);

# %%
tracts.set_geometry('geometry', inplace=True)
tracts.plot(column='centest', legend=True);

# %% [markdown]
# #### Zonal Methods of Surface to Area Interpolation

# %%
import rasterstats

# %%
gdf.head()

# %%
tracts.plot()

# %%
from rasterstats import zonal_stats
tstats = zonal_stats(tracts, "clipped_example.tif",
            stats="count min mean max median")

#elevations2 = zonal_stats(
#    sd_tracts.to_crs(dem.rio.crs),  # Geotable with zones
#    "../data/nasadem/nasadem_sd.tif",  # Path to surface file
#)
#elevations2 = pandas.DataFrame(elevations2)

# %%
tstats[:5]

# %%
tstats = pd.DataFrame(tstats)

# %%
tstats.head()

# %%
tstats.shape

# %%
tracts.shape

# %%
tracts['mean'] = tstats['mean'].values
tracts.plot(column='mean', legend=True);

# %%
tracts['median'] = tstats['median'].values
tracts.plot(column='median', legend=True);

# %%
tracts['range'] = tstats['max'].values - tstats['min'].values
tracts.plot(column='range', legend=True);

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(data=tracts, x='centest', y='mean')
plt.plot([10, 40], [10, 40]);

# %%
sns.scatterplot(data=tracts, x='median', y='mean')
plt.plot([10, 40], [10, 40]);
