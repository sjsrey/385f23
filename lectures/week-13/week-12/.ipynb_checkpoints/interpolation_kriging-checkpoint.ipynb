# %% [markdown]
# # Spatial Interpolation: Kriging
#
# - non-deterministic interpolation
# - measures of uncertainty

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 9)

# %%
import rasterio

# %%
from rasterio.mask import mask
import geopandas as gpd
import fiona
import pandas as pd
import pykrige

# %%
precip = gpd.read_file("precip_sd.geojson")

# %%
precip.plot(column='inches', legend=True);

# %%
county = gpd.read_file("sdcounty.geojson")

# %%
m = county.explore()
precip.explore(column='inches', m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_046baccf266e1de6170b9ec8320500e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_046baccf266e1de6170b9ec8320500e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_046baccf266e1de6170b9ec8320500e2 = L.map(
#                 &quot;map_046baccf266e1de6170b9ec8320500e2&quot;,
#                 {
#                     center: [33.01692888387243, -116.84601082562747],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_046baccf266e1de6170b9ec8320500e2);
#
#
#
#
#
#             var tile_layer_14fd327195da3582b3f3438307aae3e5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_046baccf266e1de6170b9ec8320500e2);
#
#
#             map_046baccf266e1de6170b9ec8320500e2.fitBounds(
#                 [[32.528832, -117.61108067385622], [33.50502576774486, -116.08094097739871]],
#                 {}
#             );
#
#
#         function geo_json_acab4b7b54885a225af5f5784e249cf7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_acab4b7b54885a225af5f5784e249cf7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_acab4b7b54885a225af5f5784e249cf7_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_acab4b7b54885a225af5f5784e249cf7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_acab4b7b54885a225af5f5784e249cf7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_acab4b7b54885a225af5f5784e249cf7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_acab4b7b54885a225af5f5784e249cf7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_acab4b7b54885a225af5f5784e249cf7 = L.geoJson(null, {
#                 onEachFeature: geo_json_acab4b7b54885a225af5f5784e249cf7_onEachFeature,
#
#                 style: geo_json_acab4b7b54885a225af5f5784e249cf7_styler,
#                 pointToLayer: geo_json_acab4b7b54885a225af5f5784e249cf7_pointToLayer
#         });
#
#         function geo_json_acab4b7b54885a225af5f5784e249cf7_add (data) {
#             geo_json_acab4b7b54885a225af5f5784e249cf7
#                 .addData(data)
#                 .addTo(map_046baccf266e1de6170b9ec8320500e2);
#         }
#             geo_json_acab4b7b54885a225af5f5784e249cf7

# %% [markdown]
# ### Interpolate to Grids

# %%
import tobler

# %%
county_utm = county.to_crs(county.estimate_utm_crs())
precip_utm = precip.to_crs(precip.estimate_utm_crs())

# %%
from tobler.util import h3fy

# %%
county_h3 = h3fy(county_utm)
# Out:
# /Users/srey/mambaforge/envs/385f23/lib/python3.10/site-packages/pyproj/crs/crs.py:1293: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %%
county_h3.plot()
# Out:
# <Axes: >

# %%
m = county_h3.plot(color='grey')
precip_utm.plot(column='inches', ax=m, legend=True);

# %%
county_h3.shape
# Out:
# (283, 1)

# %%
import pykrige.kriging_tools as kt
from pykrige.ok import OrdinaryKriging
import numpy

data = numpy.array(
    [
        [0.3, 1.2, 0.47],
        [1.9, 0.6, 0.56],
        [1.1, 3.2, 0.74],
        [3.3, 4.4, 1.47],
        [4.7, 3.8, 1.74],
    ]
)

gridx = numpy.arange(0.0, 5.5, 0.5)
gridy = numpy.arange(0.0, 5.5, 0.5)

# %%
OK = OrdinaryKriging(
    data[:, 0],
    data[:, 1],
    data[:, 2],
    variogram_model="linear",
    verbose=False,
    enable_plotting=False,
)

# %%
z, ss = OK.execute("grid", gridx, gridy)

# %%
kt.write_asc_grid(gridx, gridy, z, filename="output.asc")
plt.imshow(z)
plt.show()

# %%
OK.display_variogram_model()

# %%
# on our data

# %%
# need data as an array x, y, z
xy = precip_utm.get_coordinates().values
xy
# Out:
# array([[ 583276.80289131, 3625390.67293517],
#        [ 493933.62479103, 3645191.67808526],
#        [ 456222.02679589, 3688271.33956234],
#        [ 509721.92410575, 3672156.41981747],
#        [ 520494.02043271, 3607537.11508328],
#        [ 509197.52913975, 3604682.45610134],
#        [ 503345.4275951 , 3614118.12035294],
#        [ 463079.40194729, 3664566.49645636],
#        [ 560092.39313777, 3648803.80879726],
#        [ 481520.33845466, 3615240.79639166],
#        [ 484817.62561721, 3625137.78805091],
#        [ 487166.58089363, 3605859.26820384],
#        [ 484257.09670148, 3687766.56981735],
#        [ 519505.13573838, 3640553.90522831],
#        [ 523222.53593187, 3692497.76751362],
#        [ 554354.03533342, 3688831.87397658],
#        [ 475511.9319246 , 3660330.40098719],
#        [ 574804.39500283, 3642367.56894347],
#        [ 567368.55725305, 3659349.32470879],
#        [ 540758.12280467, 3652054.7289456 ],
#        [ 550098.80842923, 3621975.18196813],
#        [ 569707.79919443, 3610353.58424473],
#        [ 583602.41813378, 3660985.97690346],
#        [ 553142.39667086, 3635622.82370449],
#        [ 541679.58175618, 3689534.51950215]])

# %%
z = precip_utm.inches.values
z
# Out:
# array([ 7, 18, 21, 29, 24, 20, 18, 15,  8, 13, 16, 14, 20, 24, 25,  9, 16,
#         6, 11, 43, 29, 20,  4, 36, 28])

# %%
z = z.reshape(-1, 1)

# %%
data = numpy.hstack([xy,z])

# %%
OK = OrdinaryKriging(
    data[:, 0],
    data[:, 1],
    data[:, 2],
    variogram_model='gaussian',
    verbose=False,
    enable_plotting=False
)

# %%
OK.display_variogram_model()

# %%
data.shape
# Out:
# (25, 3)

# %%
OK.get_variogram_points()
# Out:
# (array([ 22691.98319722,  42701.1810314 ,  64917.96420437,  86804.46597716,
#         106790.56860676, 130641.17425937]),
#  array([81.78486823, 81.78486823, 81.78486823, 81.78486823, 81.78486823,
#         81.78486823]))

# %%
OK.print_statistics()
# Out:
# Q1 = None
# Q2 = None
# cR = None

# %%
targetxy = county_h3.centroid.get_coordinates().values
targetxy
# Out:
# array([[ 581907.13565102, 3642506.78604697],
#        [ 500118.68477071, 3697394.66980541],
#        [ 511998.94775042, 3603042.72383735],
#        [ 480054.79567002, 3656724.39312364],
#        [ 477835.57794054, 3650187.61561909],
#        [ 549808.44181779, 3696149.07033509],
#        [ 577192.40145761, 3665760.2561693 ],
#        [ 482480.03556365, 3626967.64640108],
#        [ 529500.93326998, 3691715.69554688],
#        [ 538609.31840618, 3681596.35712122],
#        [ 466443.22028213, 3671905.48170568],
#        [ 493468.71687325, 3677801.74876646],
#        [ 540951.4197815 , 3669992.23386757],
#        [ 556849.33069121, 3661331.49043028],
#        [ 464128.78440446, 3683489.40298434],
#        [ 570269.91913357, 3682442.27444586],
#        [ 516204.41915619, 3652483.90886177],
#        [ 563491.78812276, 3680964.50731512],
#        [ 513986.71495783, 3645940.82519058],
#        [ 538862.30450503, 3645288.3164358 ],
#        [ 543037.75451731, 3694670.91363072],
#        [ 450541.31151193, 3698638.64152863],
#        [ 475315.78608841, 3698016.85901103],
#        [ 554899.35007287, 3618420.43160099],
#        [ 486814.77678114, 3658197.12789844],
#        [ 566118.11557144, 3633003.74472013],
#        [ 570549.36801578, 3646110.08179632],
#        [ 559063.99729545, 3667877.11736235],
#        [ 507217.60265329, 3644468.15567276],
#        [ 531839.22111051, 3680119.80115536],
#        [ 484491.99131678, 3669794.16538958],
#        [ 511422.98127822, 3693817.81685226],
#        [ 541332.93554256, 3615477.29740698],
#        [ 561141.80045457, 3692568.01766417],
#        [ 554367.62236942, 3691089.74517694],
#        [ 520638.46887256, 3665566.31345934],
#        [ 522734.81573275, 3690238.6341899 ],
#        [ 520995.04589173, 3611065.38941823],
#        [ 480259.56432811, 3620423.48811285],
#        [ 468661.9879105 , 3678435.28918643],
#        [ 480157.05798591, 3638581.16885276],
#        [ 543550.98423572, 3622031.53081721],
#        [ 557116.61417562, 3624975.97208755],
#        [ 491357.91967806, 3653132.18596899],
#        [ 470978.4224601 , 3666847.28058459],
#        [ 513754.44048113, 3682227.78948974],
#        [ 486919.79219592, 3640052.36185931],
#        [ 574694.63778653, 3695525.65957387],
#        [ 534427.85612827, 3632190.86526525],
#        [ 482273.60252217, 3663259.91418326],
#        [ 473197.19848035, 3673378.99981059],
#        [ 502557.11714058, 3667681.10990864],
#        [ 525432.97115112, 3624168.74788311],
#        [ 563628.84645946, 3662807.37717906],
#        [ 581763.06379006, 3660687.82060233],
#        [ 505224.05714111, 3601573.86511973],
#        [ 547985.68950375, 3635136.41739147],
#        [ 500671.43148358, 3606656.83344106],
#        [ 459504.74830991, 3706635.13983668],
#        [ 491464.82842446, 3634981.52838612],
#        [ 484388.2476005 , 3687913.67832686],
#        [ 534054.14930048, 3686657.12171865],
#        [ 529991.57611324, 3619088.57708364],
#        [ 504999.06331614, 3637924.47659629],
#        [ 459690.8528733 , 3670432.32938913],
#        [ 509549.98374947, 3632850.96244659],
#        [ 507444.36985903, 3608125.9796515 ],
#        [ 482376.70546813, 3645121.05928847],
#        [ 514218.91071555, 3609595.49831108],
#        [ 459597.59750026, 3688541.3362586 ],
#        [ 566254.99915271, 3614807.02139527],
#        [ 487024.99892817, 3621893.11247481],
#        [ 529869.12971131, 3637267.33695641],
#        [ 475716.57536843, 3625497.74300614],
#        [ 496120.70667928, 3611737.70086973],
#        [ 577476.58089932, 3629395.42306641],
#        [ 523214.22575961, 3617617.65805056],
#        [ 495794.3604861 , 3666207.01111569],
#        [ 493900.10373837, 3605188.05968114],
#        [ 498231.14759982, 3636452.81764868],
#        [ 475415.56003512, 3679909.42914708],
#        [ 559333.39850698, 3631530.31693728],
#        [ 545897.24317585, 3610392.61237033],
#        [ 545768.57128448, 3628584.57533177],
#        [ 556715.15757856, 3679487.10697619],
#        [ 509207.20776815, 3687285.6069007 ],
#        [ 509435.70767413, 3651010.60182066],
#        [ 497902.48207508, 3690865.01837731],
#        [ 534303.46406952, 3650361.04840386],
#        [ 520876.26148723, 3629246.796243  ],
#        [ 552418.49075707, 3648236.43998531],
#        [ 554634.15946495, 3654784.59347725],
#        [ 577617.89146443, 3611191.30021612],
#        [ 470880.34286143, 3684963.79678685],
#        [ 579549.16978577, 3654137.12273377],
#        [ 495903.02153841, 3648065.09341577],
#        [ 531962.95386706, 3661974.72910769],
#        [ 471175.53141375, 3630569.8787541 ],
#        [ 561278.15214655, 3674421.46080732],
#        [ 480362.31267391, 3602251.6295175 ],
#        [ 502780.09685021, 3631379.57807309],
#        [ 581618.44372672, 3678853.994039  ],
#        [ 554766.92518636, 3636609.74960759],
#        [ 547855.72509405, 3653309.70936795],
#        [ 466347.13741195, 3690015.98167061],
#        [ 557249.71599841, 3606776.62828077],
#        [ 559467.53478796, 3613335.1787323 ],
#        [ 504661.95265601, 3692341.23531721],
#        [ 527286.03940175, 3685180.31193626],
#        [ 464224.04714747, 3665374.38769879],
#        [ 484700.11392318, 3633510.60881323],
#        [ 538735.91686106, 3663449.7742359 ],
#        [ 583976.42415911, 3667237.24839477],
#        [ 579692.11534581, 3635951.7142245 ],
#        [ 498011.93044756, 3672742.51551662],
#        [ 561414.11876934, 3656259.8466624 ],
#        [ 525191.53646561, 3660500.05194954],
#        [ 532209.94148314, 3625640.31903308],
#        [ 504886.63968499, 3656078.22837041],
#        [ 479851.01109363, 3692966.36474271],
#        [ 575260.53946955, 3622837.9261439 ],
#        [ 489033.18623708, 3664733.27920456],
#        [ 477633.49995864, 3686438.55523779],
#        [ 493576.35450641, 3659670.23012892],
#        [ 505111.53671636, 3619756.2624712 ],
#        [ 500450.07266063, 3642995.8552746 ],
#        [ 545639.62799492, 3646762.19338669],
#        [ 486605.32867694, 3694442.10238089],
#        [ 563901.74175685, 3626448.75054093],
#        [ 529623.80481807, 3673581.1737319 ],
#        [ 570688.40008477, 3627921.90086846],
#        [ 525070.65929167, 3678643.61145616],
#        [ 516087.34509082, 3670630.408107  ],
#        [ 464033.8926492 , 3701589.28837239],
#        [ 552550.21433112, 3630057.26047312],
#        [ 511768.56742815, 3639396.50522414],
#        [ 524949.68001172, 3696772.07366292],
#        [ 543294.86385204, 3658380.82246402],
#        [ 534178.89392431, 3668516.55966102],
#        [ 545380.94297508, 3683073.27934392],
#        [ 506990.96781518, 3680752.07684591],
#        [ 513870.5860591 , 3664091.74148071],
#        [ 518185.55978598, 3695294.76297129],
#        [ 545510.41724314, 3664925.18732641],
#        [ 548115.36614168, 3616948.6782854 ],
#        [ 468565.07236487, 3696541.23718432],
#        [ 518539.65177845, 3640868.90352726],
#        [ 500229.05722977, 3679276.72993491],
#        [ 477937.01221678, 3632040.05893447],
#        [ 541078.82388874, 3651835.19434128],
#        [ 536770.49833912, 3620559.8680068 ],
#        [ 575119.80938638, 3641031.970811  ],
#        [ 536268.58226451, 3693193.12203088],
#        [ 568195.5947636 , 3657735.46891642],
#        [ 488927.48605441, 3682858.80468817],
#        [ 532086.52850423, 3643814.80913851],
#        [ 531715.33377619, 3698249.7489156 ],
#        [ 543423.04960131, 3640213.43774119],
#        [ 536519.92924093, 3656906.04126146],
#        [ 558928.74106031, 3686028.22251955],
#        [ 491251.1686566 , 3671268.15729212],
#        [ 470782.58211196, 3703065.15622227],
#        [ 452759.68652329, 3705159.39057461],
#        [ 493792.0503442 , 3623363.10763833],
#        [ 568056.75376205, 3675898.60453102],
#        [ 570826.96433774, 3609719.36936614],
#        [ 527407.90755585, 3667041.2528555 ],
#        [ 518775.43875632, 3604511.95555277],
#        [ 509664.27341557, 3614676.93566514],
#        [ 493361.22261052, 3695918.20407225],
#        [ 556580.63594389, 3697627.59213246],
#        [ 491571.89255932, 3616816.46225848],
#        [ 543166.43086289, 3676533.40671277],
#        [ 484804.4885563 , 3615347.11917883],
#        [ 509321.44805974, 3669155.5755752 ],
#        [ 504774.2685571 , 3674217.24005431],
#        [ 473098.27797215, 3691490.99116893],
#        [ 487130.39476031, 3603719.65837294],
#        [ 511653.37119958, 3657551.80157358],
#        [ 536394.35114935, 3675057.10680736],
#        [ 559198.88456302, 3649711.05622564],
#        [ 489351.33828972, 3610268.64132352],
#        [ 502668.57241713, 3649537.66333655],
#        [ 565843.06049877, 3669353.63429136],
#        [ 520757.40141292, 3647413.86382234],
#        [ 478038.70743527, 3613878.14745356],
#        [ 561684.87910303, 3619892.55735116],
#        [ 479952.77938029, 3674852.88369504],
#        [ 556983.15098435, 3643161.01936881],
#        [ 552286.44679717, 3666400.96837126],
#        [ 448322.53092099, 3692116.55282217],
#        [ 493684.13312913, 3641523.92400165],
#        [ 572764.23233462, 3652661.39760635],
#        [ 572482.54950721, 3688984.63059996],
#        [ 500560.71045137, 3624833.47360029],
#        [ 554501.05711808, 3672944.6844495 ],
#        [ 502445.73368043, 3685809.64098992],
#        [ 495685.82372913, 3684334.04024898],
#        [ 547725.47691932, 3671468.27546663],
#        [ 561549.69589247, 3638083.45258616],
#        [ 516438.45546785, 3616147.11091024],
#        [ 573043.99822364, 3616279.23704335],
#        [ 507330.97111252, 3626304.2103574 ],
#        [ 547594.9489972 , 3689611.83834967],
#        [ 541205.99707737, 3633663.45594252],
#        [ 567917.47501119, 3694046.65580025],
#        [ 525553.52198937, 3605981.56026501],
#        [ 486709.95488198, 3676327.13335005],
#        [ 527529.65384522, 3648887.27156213],
#        [ 477734.40654853, 3668320.53981759],
#        [ 527651.27486573, 3630718.64536402],
#        [ 565704.89811186, 3687506.24345192],
#        [ 549940.03574704, 3678010.07343886],
#        [ 468759.23914851, 3660314.28484139],
#        [ 515970.23784024, 3688761.9379709 ],
#        [ 489245.11462219, 3628437.92004637],
#        [ 498340.91132366, 3618286.17669011],
#        [ 466539.65572805, 3653780.02596927],
#        [ 572904.35727229, 3634477.54381736],
#        [ 568333.99337776, 3639557.52632232],
#        [ 534552.06649684, 3614006.28896818],
#        [ 579834.52373656, 3617751.82567418],
#        [ 520519.46706736, 3683703.86785654],
#        [ 565980.80117272, 3651186.04210145],
#        [ 511883.76059215, 3621226.71959902],
#        [ 570409.8728011 , 3664283.63242803],
#        [ 457378.83267104, 3682015.37384039],
#        [ 550071.33374351, 3659855.97218942],
#        [ 577334.7492726 , 3647585.16829583],
#        [ 496011.80442737, 3629908.56393834],
#        [ 518421.67284947, 3659025.74276903],
#        [ 498121.48646279, 3654605.02316659],
#        [ 522974.69869809, 3653957.58445341],
#        [ 552681.61338201, 3611863.70905665],
#        [ 525312.30819761, 3642341.67150049],
#        [ 452849.66631204, 3687067.05494359],
#        [ 461815.95321193, 3695065.97886969],
#        [ 471076.81921702, 3648715.88247967],
#        [ 574836.85371055, 3677376.11561139],
#        [ 552154.08660202, 3684550.56781343],
#        [ 581473.28051663, 3697005.02897353],
#        [ 579261.68698566, 3690463.38395296],
#        [ 582050.65428164, 3624311.16918039],
#        [ 572623.6281565 , 3670830.51914983],
#        [ 550202.33171713, 3641687.04345226],
#        [ 523094.50835151, 3635794.84189274],
#        [ 491144.57767927, 3689389.16604358],
#        [ 511538.17484064, 3675692.33089624],
#        [ 461910.02050218, 3676961.51444519],
#        [ 489139.06317909, 3646592.89206442],
#        [ 564037.56976226, 3608247.81205381],
#        [ 457286.79975903, 3700113.78347051],
#        [ 482583.59072836, 3608799.95368074],
#        [ 455068.43670844, 3693591.08407855],
#        [ 540823.788568  , 3688134.29719332],
#        [ 532333.18926804, 3607451.53797293],
#        [ 507104.2672883 , 3662617.53692759],
#        [ 514102.82417831, 3627775.31790619],
#        [ 568471.94498738, 3621365.05553311],
#        [ 475515.61745789, 3661786.91605965],
#        [ 475615.95652224, 3643649.59509369],
#        [ 473495.75465651, 3618954.2345554 ],
#        [ 538988.47759607, 3627112.26151716],
#        [ 579405.6920067 , 3672307.7719291 ],
#        [ 583830.64951416, 3685398.90904263],
#        [ 473296.41928557, 3655252.02581161],
#        [ 522854.80006912, 3672105.60749547],
#        [ 574978.57919265, 3659211.46023217],
#        [ 527772.76721403, 3612535.65297123],
#        [ 518303.64114164, 3677167.7880333 ],
#        [ 539114.43239871, 3608921.8886752 ],
#        [ 502891.68776826, 3613207.1323176 ],
#        [ 482170.72878439, 3681383.93431757],
#        [ 536645.31286168, 3638740.20224087],
#        [ 529746.53812268, 3655431.62858892],
#        [ 484595.94746372, 3651659.71678432],
#        [ 473395.93861175, 3637110.34498703],
#        [ 516321.45697173, 3634322.71705461],
#        [ 500339.52072109, 3661143.69980778],
#        [ 550333.02558962, 3623503.56551186],
#        [ 563765.49916656, 3644635.36548538],
#        [ 518657.5747936 , 3622697.54807068],
#        [ 577049.54235358, 3683920.40835841]])

# %%
z, ss = OK.execute('points', targetxy[:,0], targetxy[:,1])

# %%
z
# Out:
# masked_array(data=[18.959999999998303, 18.960000000000342,
#                    18.96000000000034, 18.95999999999982,
#                    18.959999999999813, 18.960000000000075,
#                    18.95999999999846, 18.959999999999482,
#                    18.960000000000914, 18.960000000000704,
#                    18.959999999999845, 18.96000000000046,
#                    18.960000000000882, 18.959999999999738,
#                    18.960000000000136, 18.95999999999952,
#                    18.96000000000091, 18.959999999999514,
#                    18.960000000000754, 18.960000000002136,
#                    18.960000000000438, 18.96000000000023,
#                    18.960000000000203, 18.960000000001216,
#                    18.959999999999997, 18.959999999999837,
#                    18.959999999998388, 18.95999999999947,
#                    18.960000000000438, 18.960000000000917,
#                    18.96000000000008, 18.96000000000068,
#                    18.960000000001067, 18.959999999999706,
#                    18.959999999999848, 18.96000000000109,
#                    18.960000000000942, 18.96000000000057,
#                    18.959999999999336, 18.960000000000004,
#                    18.9599999999998, 18.960000000001482,
#                    18.960000000001262, 18.96000000000006,
#                    18.959999999999738, 18.960000000001003,
#                    18.959999999999837, 18.9599999999999,
#                    18.960000000001507, 18.959999999999912,
#                    18.959999999999912, 18.960000000000758,
#                    18.96000000000078, 18.95999999999893,
#                    18.95999999999826, 18.960000000000118,
#                    18.960000000001944, 18.959999999999873,
#                    18.960000000000186, 18.959999999999802,
#                    18.960000000000246, 18.96000000000087,
#                    18.960000000000825, 18.96000000000026,
#                    18.959999999999862, 18.96000000000036,
#                    18.96000000000018, 18.959999999999855,
#                    18.960000000000424, 18.960000000000225,
#                    18.96000000000032, 18.95999999999937,
#                    18.960000000001454, 18.959999999999546,
#                    18.9599999999996, 18.959999999998903,
#                    18.960000000000637, 18.96000000000045,
#                    18.959999999999585, 18.96000000000001,
#                    18.960000000000075, 18.960000000000914,
#                    18.960000000000843, 18.960000000001852,
#                    18.95999999999969, 18.960000000000797,
#                    18.960000000000615, 18.960000000000427,
#                    18.96000000000199, 18.960000000000708,
#                    18.96000000000103, 18.960000000000285,
#                    18.959999999999773, 18.96000000000014,
#                    18.95999999999801, 18.960000000000118,
#                    18.960000000001443, 18.95999999999978,
#                    18.959999999999447, 18.9599999999995,
#                    18.960000000000086, 18.959999999999468,
#                    18.96000000000131, 18.960000000001376,
#                    18.960000000000207, 18.960000000000566,
#                    18.96000000000075, 18.960000000000548,
#                    18.96000000000099, 18.95999999999974,
#                    18.959999999999688, 18.960000000001354,
#                    18.959999999998715, 18.95999999999853,
#                    18.96000000000064, 18.959999999999155,
#                    18.96000000000128, 18.9600000000011,
#                    18.960000000000544, 18.960000000000218,
#                    18.95999999999938, 18.960000000000154,
#                    18.96000000000017, 18.960000000000242,
#                    18.96000000000004, 18.960000000000168,
#                    18.960000000001926, 18.96000000000025,
#                    18.960000000000463, 18.96000000000101,
#                    18.95999999999954, 18.960000000001017,
#                    18.960000000001067, 18.960000000000218,
#                    18.96000000000169, 18.96000000000055,
#                    18.960000000000814, 18.960000000001514,
#                    18.96000000000112, 18.96000000000032,
#                    18.960000000000882, 18.960000000000978,
#                    18.960000000000772, 18.9600000000009,
#                    18.960000000001262, 18.96000000000022,
#                    18.960000000000893, 18.96000000000071,
#                    18.959999999999678, 18.96000000000201,
#                    18.96000000000113, 18.959999999998377,
#                    18.960000000000743, 18.95999999999838,
#                    18.960000000000328, 18.960000000001823,
#                    18.960000000000754, 18.960000000002093,
#                    18.960000000001813, 18.95999999999966,
#                    18.96000000000033, 18.960000000000186,
#                    18.960000000000186, 18.95999999999959,
#                    18.959999999999262, 18.960000000000075,
#                    18.960000000001152, 18.96000000000051,
#                    18.960000000000246, 18.960000000000285,
#                    18.959999999999848, 18.959999999999393,
#                    18.960000000000537, 18.95999999999925,
#                    18.96000000000096, 18.960000000000885,
#                    18.960000000000203, 18.95999999999945,
#                    18.960000000000807, 18.960000000000864,
#                    18.959999999999752, 18.95999999999935,
#                    18.96000000000036, 18.959999999999035,
#                    18.960000000001127, 18.95999999999933,
#                    18.960000000000758, 18.960000000000043,
#                    18.96000000000059, 18.960000000000168,
#                    18.960000000000235, 18.95999999999997,
#                    18.959999999998068, 18.959999999999738,
#                    18.959999999999887, 18.95999999999986,
#                    18.96000000000065, 18.960000000000488,
#                    18.9600000000004, 18.960000000000196,
#                    18.960000000000466, 18.959999999999816,
#                    18.960000000000196, 18.960000000000186,
#                    18.960000000001934, 18.959999999999763,
#                    18.960000000000573, 18.96000000000023,
#                    18.9600000000016, 18.95999999999988,
#                    18.960000000001056, 18.959999999999624,
#                    18.960000000000093, 18.959999999999706,
#                    18.960000000000907, 18.95999999999958,
#                    18.959999999999713, 18.959999999999756,
#                    18.959999999998917, 18.959999999999063,
#                    18.96000000000081, 18.9599999999994,
#                    18.960000000001024, 18.95999999999864,
#                    18.960000000000345, 18.9599999999985,
#                    18.960000000000132, 18.960000000000715,
#                    18.95999999999806, 18.95999999999981,
#                    18.960000000001042, 18.960000000000303,
#                    18.96000000000127, 18.960000000000925,
#                    18.960000000001344, 18.960000000000218,
#                    18.96000000000024, 18.959999999999816,
#                    18.959999999999326, 18.95999999999993,
#                    18.960000000000008, 18.95999999999987,
#                    18.95999999999901, 18.959999999998885,
#                    18.960000000001656, 18.960000000001,
#                    18.960000000000328, 18.96000000000102,
#                    18.959999999999983, 18.959999999999937,
#                    18.960000000000388, 18.96000000000022,
#                    18.959999999999308, 18.960000000000225,
#                    18.960000000000576, 18.960000000000598,
#                    18.96000000000079, 18.96000000000046,
#                    18.960000000000047, 18.959999999999752,
#                    18.95999999999983, 18.9599999999995,
#                    18.960000000001543, 18.959999999998985,
#                    18.959999999999805, 18.95999999999974,
#                    18.96000000000105, 18.95999999999811,
#                    18.960000000000676, 18.96000000000106,
#                    18.960000000000715, 18.95999999999993,
#                    18.960000000000186, 18.960000000001912,
#                    18.960000000001635, 18.959999999999898,
#                    18.959999999999837, 18.960000000000644,
#                    18.960000000000527, 18.960000000001617,
#                    18.95999999999933, 18.960000000000537,
#                    18.959999999999653],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False],
#        fill_value=1e+20)

# %%
z.data.shape
# Out:
# (283,)

# %%
targetxy.shape
# Out:
# (283, 2)

# %%
county_h3['ok_est'] = z.data

# %%
county_h3.plot(column='ok_est')
# Out:
# <Axes: >

# %% [markdown]
# ### Nearest neighbor

# %%
hcents = county_h3.centroid

# %%
m = hcents.plot(color='r')
precip_utm.plot(column='inches', ax=m, legend=True);

# %%
gpd.sjoin_nearest(county_h3, precip_utm, distance_col="distances",
    lsuffix="left", rsuffix="right", exclusive=True)
# Out:
#                                                           geometry  ok_est  \
# hex_id
# 8629a69afffffff  POLYGON ((582693.113 3638628.699, 585694.397 3...   18.96
# 8629a692fffffff  POLYGON ((566902.315 3629125.241, 569903.188 3...   18.96
# 8629a6827ffffff  POLYGON ((571333.955 3642233.641, 574334.208 3...   18.96
# 8629a6917ffffff  POLYGON ((580477.892 3632072.595, 583479.493 3...   18.96
# 8629a691fffffff  POLYGON ((575904.994 3637154.189, 578905.921 3...   18.96
# ...                                                            ...     ...
# 8629a6867ffffff  POLYGON ((555416.738 3650911.149, 558415.282 3...   18.96
# 8629a695fffffff  POLYGON ((559982.072 3645836.264, 562981.290 3...   18.96
# 8629a6947ffffff  POLYGON ((557766.151 3639285.187, 560765.676 3...   18.96
# 8629a682fffffff  POLYGON ((566764.786 3647310.947, 569764.365 3...   18.96
# 8629a6957ffffff  POLYGON ((564549.292 3640759.229, 567549.184 3...   18.96
#
#                  index_right  inches    distances
# hex_id
# 8629a69afffffff           17       6  3515.983630
# 8629a692fffffff           17       6  8778.018507
# 8629a6827ffffff           17       6  2210.016996
# 8629a6917ffffff           17       6  4623.339483
# 8629a691fffffff           17       6     0.000000
# ...                      ...     ...          ...
# 8629a6867ffffff            8       8  4684.919927
# 8629a695fffffff            8       8     0.000000
# 8629a6947ffffff            8       8  2861.893210
# 8629a682fffffff            8       8  2773.550327
# 8629a6957ffffff            8       8  2141.222724
#
# [283 rows x 5 columns]

# %%
county_h3.shape
# Out:
# (283, 2)

# %%
county_h3['nn1_est'] = gpd.sjoin_nearest(county_h3, precip_utm, distance_col="distances",
    lsuffix="left", rsuffix="right", exclusive=True).inches

# %%
county_h3.plot(column='nn1_est', legend=True);

# %% [markdown]
# ### Knn5

# %%
X = [[0], [1], [2], [3]]
y = [0, 0, 1, 1]
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X, y)
print(neigh.predict([[1.5]]))
# Out:
# [0.5]

# %%
# Set number of neighbors to use
neighbors = 5

# Initialize KNN regressor
knn_regressor = KNeighborsRegressor(n_neighbors = neighbors, weights = "uniform") # no distance decay distance

# Fit to observed locations
knn_regressor.fit(precip_utm.get_coordinates(), precip_utm.inches)
# Out:
# KNeighborsRegressor()

# %%
knn_regressor.predict(hcents.get_coordinates())
# Out:
# array([ 7.2, 23.6, 17.8, 17. , 15.6, 23.2,  7.6, 15.8, 26.8, 26.8, 18. ,
#        19.6, 19.8, 20.8, 20.2, 12. , 26.4, 12. , 26.4, 28. , 26.8, 20.2,
#        20.2, 20. , 19.6, 17.2, 13. , 15. , 21. , 26.8, 19.6, 22.2, 26.6,
#        15.4, 23.2, 29.8, 22.2, 23. , 15.8, 20.2, 15.6, 30.4, 19.8, 18.8,
#        18. , 29. , 16.2, 12. , 31.2, 19.6, 18. , 21.4, 23. , 14.4,  7.2,
#        17.8, 24.4, 17.8, 20.2, 17.8, 20.2, 26.8, 23. , 17.8, 18. , 20. ,
#        17.8, 15.6, 20. , 20.2, 19.6, 15.8, 31.2, 15.8, 16.2, 15.4, 23. ,
#        19.6, 16.2, 17.8, 20.2, 19.8, 25.8, 28. , 19.8, 23.6, 26. , 22.2,
#        28. , 23. , 20.8, 20.8, 19.6, 20.2,  7.2, 20.6, 26.4, 15.4, 12. ,
#        16.2, 17.8,  7.6, 24.4, 20.8, 20.2, 23.2, 19.6, 23.6, 26.8, 18. ,
#        15.8, 19.8,  7.6,  7.2, 21.6, 20.8, 29.8, 31.2, 26. , 20.2, 19.6,
#        19.6, 20.2, 19.6, 18.4, 18.4, 25.4, 22.2, 19.6, 26.8, 19.6, 26.8,
#        29.8, 20.2, 24.4, 23.8, 22.2, 24.4, 26.8, 23.2, 23.6, 27.8, 22.2,
#        19.8, 23.4, 20.2, 26.4, 21.6, 15.4, 24.4, 31.2,  7.2, 26.8, 13. ,
#        20.2, 28. , 26.8, 28. , 28. , 15.4, 19.6, 20.2, 20.2, 15.8, 12. ,
#        19.6, 29.8, 21. , 18.4, 22.2, 15.4, 16.2, 23.2, 16.2, 23.2, 21.6,
#        20.2, 16.2, 26. , 26.8, 20.8, 16.2, 20.6,  7.6, 30. , 16.2, 19.6,
#        20.2, 20.8, 19.8, 20.2, 17.4, 13. , 12. , 17. , 19.8, 23.6, 21. ,
#        19.8, 18. , 20. , 19.6, 20.4, 23.2, 28. , 15.4, 23. , 19.6, 28. ,
#        18. , 31.2, 12. , 23.2, 18. , 22.2, 15.8, 16.2, 17.2, 15.4, 13.6,
#        26.6, 19.6, 22.2, 13. , 20.4,  7.6, 18. , 21.4,  7.2, 15.8, 27.8,
#        20.6, 30. , 23.2, 30. , 18. , 20.2, 15.6,  7.6, 23.2, 12. , 12. ,
#        19.6,  7.6, 24.4, 29. , 22.2, 24. , 18. , 17.8, 19.6, 20.2, 16.2,
#        20.2, 26.8, 25.4, 22.4, 20.8, 19.6, 18. , 15.6, 15.8, 31.2,  7.6,
#        12. , 17. , 29.8, 13. , 23. , 29. , 25.8, 17.8, 20.2, 28. , 28. ,
#        18.8, 15.6, 25.4, 21.4, 27.2, 20.8, 23. , 12. ])

# %%
county_h3['nn5_est'] = knn_regressor.predict(hcents.get_coordinates())

# %%
county_h3.plot(column='nn5_est', legend=True);

# %%
import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
county_h3.plot(column='nn1_est',ax=ax1)
county_h3.plot(column='nn5_est',ax=ax2)
ax1.set_title("knn=1")
ax2.set_title("knn=5");

# %%
# Set number of neighbors to use
neighbors = 5

# Initialize KNN regressor
knn_regressor = KNeighborsRegressor(n_neighbors = neighbors, weights = "distance") # inverse distance weighting
# Fit to observed locations
knn_regressor.fit(precip_utm.get_coordinates(), precip_utm.inches)
# Out:
# KNeighborsRegressor(weights='distance')

# %%
county_h3['nn5id_est'] = knn_regressor.predict(hcents.get_coordinates())

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
county_h3.plot(column='nn5_est',ax=ax1)
county_h3.plot(column='nn5id_est',ax=ax2)
ax1.set_title("knn=5 (Unweighted)")
ax2.set_title("knn=5 (Inverse Distance Weights)");

# %% [markdown]
# ## Fit

# %%
h3_cents = county_h3.centroid
import rioxarray
import rasterio

# %%
# get observed values for all grid cells


clipped = rasterio.open("clipped_example.tif")

# %%
clipped.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': None,
#  'width': 527,
#  'height': 336,
#  'count': 1,
#  'crs': CRS.from_epsg(4326),
#  'transform': Affine(0.002913805220117985, 0.0, -117.61397387622179,
#         0.0, -0.0029142217548938525, 33.50612487372884)}

# %%
h3_cents_4326 = h3_cents.to_crs(clipped.meta['crs'])
cp = h3_cents_4326
coord_list = [(x, y) for x, y in zip(cp.x, cp.y)]

# %%
observations = [x[0] for x in clipped.sample(coord_list)]
county_h3['inches'] = observations

# %%
county_h3.plot(column='inches', legend=True)
# Out:
# <Axes: >

# %%
# calculate fit for each approach (MAPE)
def mape(est, obs):
    err = est-obs
    aerr = numpy.abs(err)
    den = obs + (obs == 0)
    paerr = aerr / den
    paerr *= 100
    return paerr.mean()

# %%
mape(county_h3.nn1_est, county_h3.inches)
# Out:
# 22.889565323272546

# %%
mape(county_h3.nn5_est, county_h3.inches)
# Out:
# 30.76128914298387

# %%
mape(county_h3.nn5id_est, county_h3.inches)
# Out:
# 24.291415712313928

# %%
mape(county_h3.ok_est, county_h3.inches)
# Out:
# 56.70394061432729

# %%
# plot fit

# %%
# map errors for different models

# %%
en1 = county_h3.nn1_est - county_h3.inches

county_h3['nn1_error'] = en1

county_h3.plot(column='nn1_error', legend=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
en5id = county_h3.nn5id_est - county_h3.inches

county_h3['nn5id_error'] = en5id

county_h3.plot(column='nn5id_error', legend=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.scatterplot(x=county_h3.inches, y=county_h3.nn5id_error);
# Out:
# /Users/srey/mambaforge/envs/385f23/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/srey/mambaforge/envs/385f23/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
